# %% [markdown]
# # hypothesis Testing

# %% [markdown]
# # Q.1

# %%
#import libraries
import pandas as pd
from scipy import stats
import numpy as np
from scipy.stats import chi2_contingency,chisquare

# %%
#loading dataset
cutlets=pd.read_csv('/content/Cutlets.csv')
cutlets
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
stats.ttest_ind(cutlets['Unit A'],cutlets['Unit B'])
# Out:
# TtestResult(statistic=0.7228688704678063, pvalue=0.4722394724599501, df=68.0)

# %% [markdown]
# #### Since p-value is greater than 0.05 we accept H0 and conclude that there is no significance difference in the diameter of the cutlet between the 2 difference units.

# %% [markdown]
# ## EDA

# %%
cutlets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 688.0 bytes

# %%
cutlets.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Two sample T-test

# %% [markdown]
# cutlets unit A -> X
#
# cutlets unit B -> Y
#
# H0 -> X==Y
#
# H1 -> X!=Y

# %%
X=cutlets['Unit A']
Y=cutlets['Unit B']

# %%
stats.ttest_ind( X,Y,alternative="two-sided")
# Out:
# TtestResult(statistic=0.7228688704678063, pvalue=0.4722394724599501, df=68.0)

# %% [markdown]
# # Inferences
#
# T Statistic = 0.72
#
# sigma = 5
#
# H0 -> 47.22%
#
# H1 -> 52.78%

# %% [markdown]
# # Q.2
#
# ---

# %% [markdown]
# * H0 : There is no difference in average TAT
#
# * Ha : There is difference in average TAT

# %%
Tat=pd.read_csv('LabTAT.csv')

# %%
Tat.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %%
p_value=stats.f_oneway(Tat.iloc[:,0],Tat.iloc[:,1],Tat.iloc[:,2],Tat.iloc[:,3])
p_value
# Out:
# F_onewayResult(statistic=118.70421654401437, pvalue=2.1156708949992414e-57)

# %%
p_value[1]
# Out:
# 2.1156708949992414e-57

# %%
if p_value[1]<0.05:
    print("H0 is rejected and there is difference of tat of all laboratories")
else:
    print("H0 is accepted and there is no difference of tat of all laboratories")
# Out:
# H0 is rejected and there is difference of tat of all laboratories

# %% [markdown]
# ## Q**.3**

# %% [markdown]
# * H0:All proportions are equal
#
# * Ha:All proportions are not equal

# %%
br=pd.read_csv('BuyerRatio.csv')

# %%
br
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
data=br.rename({'Observed Values':'Gender'},axis=1)
data
# Out:
#     Gender  East  West  North  South
# 0    Males    50   142    131     70
# 1  Females   435  1523   1356    750

# %%
obs=np.array([[50,142,131,70],[435,1523,1356,750]])

# %%
chi2_contingency(obs)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
pValue=chi2_contingency(obs)[1]

# %%
pValue
# Out:
# 0.6603094907091882

# %% [markdown]
# ##### Since p-value is greater than 0.05 we accept the null hypothesis. Therefore we can conclude that all proportions are equal

# %%
if pValue<0.05:
    print("H0 is rejected and there is no Male and female buyers are similar across in region")
else:
    print("H0 is accepted and Male and female buyers are similar across in region")
# Out:
# H0 is accepted and Male and female buyers are similar across in region

# %% [markdown]
# ## Q**.4**

# %% [markdown]
# * H0:The defective percentage dont varies by centre
#
# * Ha:The defective percentage varies by centre

# %%
cof=pd.read_csv('Costomer+OrderForm.csv')
cof
# Out:
#     Phillippines   Indonesia       Malta       India
# 0     Error Free  Error Free   Defective  Error Free
# 1     Error Free  Error Free  Error Free   Defective
# 2     Error Free   Defective   Defective  Error Free
# 3     Error Free  Error Free  Error Free  Error Free
# 4     Error Free  Error Free   Defective  Error Free
# ..           ...         ...         ...         ...
# 295   Error Free  Error Free  Error Free  Error Free
# 296   Error Free  Error Free  Error Free  Error Free
# 297   Error Free  Error Free   Defective  Error Free
# 298   Error Free  Error Free  Error Free  Error Free
# 299   Error Free   Defective   Defective  Error Free
#
# [300 rows x 4 columns]

# %%
a=pd.DataFrame(cof.Phillippines.value_counts())
a
# Out:
#             Phillippines
# Error Free           271
# Defective             29

# %%
c=pd.DataFrame(cof.value_counts())
c
# Out:
#                                                  0
# Phillippines Indonesia  Malta      India
# Error Free   Error Free Error Free Error Free  206
# Defective    Error Free Error Free Error Free   21
# Error Free   Defective  Error Free Error Free   20
#              Error Free Defective  Error Free   18
#                         Error Free Defective    16
#              Defective  Defective  Error Free    9
# Defective    Error Free Defective  Error Free    4
#              Defective  Error Free Error Free    2
#              Error Free Error Free Defective     2
# Error Free   Defective  Error Free Defective     2

# %%
cof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
print(cof['Phillippines'].value_counts())
print(cof['Indonesia'].value_counts())
print(cof['Malta'].value_counts())
print(cof['India'].value_counts())
# Out:
# Error Free    271
# Defective      29
# Name: Phillippines, dtype: int64
# Error Free    267
# Defective      33
# Name: Indonesia, dtype: int64
# Error Free    269
# Defective      31
# Name: Malta, dtype: int64
# Error Free    280
# Defective      20
# Name: India, dtype: int64

# %%
obs1=np.array([[271,267,269,280],[29,33,31,20]])
obs1
# Out:
# array([[271, 267, 269, 280],
#        [ 29,  33,  31,  20]])

# %%
chi2_contingency(obs1)
# Out:
# Chi2ContingencyResult(statistic=3.858960685820355, pvalue=0.2771020991233135, dof=3, expected_freq=array([[271.75, 271.75, 271.75, 271.75],
#        [ 28.25,  28.25,  28.25,  28.25]]))

# %%
pValue1=chi2_contingency(obs1)[1]

# %%
pValue1
# Out:
# 0.2771020991233135

# %%
if pValue<0.05:
    print("H0 is rejected")
else:
    print("H0 is accepted")
# Out:
# H0 is accepted

# %% [markdown]
# ##### Since p-value is greater than 0.05 we accept the null hypothesis. Therefore we can conclude that defective percentage of 4 centres are equal.
